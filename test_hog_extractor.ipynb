# %%
import cv2
from tsr_helpers import show_images, print_executed
from tsr_hog_extractor import HOGExtractor
from tsr_helpers import get_hog_parameters

print_executed()
# Out:
#  EXECUTED BLOCK AT 23:51:7

# %%
#start_frame = cv2.imread('./dataset/positive/00038/00008_00014.ppm')
start_frame = cv2.imread('dataset/test_images/test_10.jpg')
extractor = HOGExtractor(get_hog_parameters(), start_frame)

f = extractor.features()
print("feature shape:", f.shape)

rgb_img, a_img, b_img, c_img = extractor.visualize()
show_images([rgb_img, a_img, b_img, c_img], per_row=4, per_col=1, W=20, H=4)
print(f[0:5])
print_executed()
# Out:
# feature shape: (750,)
# [0.4824018  0.00195014 0.18350794 0.         0.21548736]
#
#  EXECUTED BLOCK AT 23:51:12
